# %%
import random
import numpy as np
import pandas as pd
from scipy import stats
from scipy.stats import kurtosis
from scipy.stats import skew

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 

from pandas.plotting import scatter_matrix

# %% [markdown]
# 1. Загрузить исходные данные data.csv

# %%
data=pd.read_csv('data.csv', ';')

# %%
data.head(20)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
# ...

# %% [markdown]
# 2. Провести первоначальный анализ предложенных данных

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %% [markdown]
# 3. Предложить стратегию по работе с пропущенными значениями в данных

# %% [markdown]
# Варианты работы с пропущенными значениями в данных:
# Удалить атрибут (столбец), содержащий null значения, если его влияние на датасет или исследуемый объект/переменную незначительно (низкая корреляция)
# Удалить строки, в которых атрибут равен null, если количество нулевых значений по строке велико.
# Заменить null значения на другое значение (0, mean, median, most popular)

# %% [markdown]
# Например, следующие атрибуты можно удалить из-за недостаточного заполнения данными
# PoolQC           7 non-null object
# Fence            281 non-null object
# MiscFeature      54 non-null object

# %%
data = data.drop("PoolQC", axis=1) 
data = data.drop("Fence", axis=1)
data = data.drop("MiscFeature", axis=1)

# %% [markdown]
# 4. Предложить стратегию по работе с категориальными переменными

# %% [markdown]
# Варианты работы с категориальными переменными:
# One hot encoding - если категорий не много (до ~10) - создаём столбцы по категориям и присваиваем им значения в зависимости от наличия данного признака (категории)
# Counts - если категорий много,  то для каждой категории считаем среднюю долю целевого события
# Weights of evidence (WOE)

# %%
data["SaleType"].value_counts()
# Out:
# WD       1267
# New       122
# COD        43
# ConLD       9
# ConLI       5
# ConLw       5
# CWD         4
# Oth         3
# Con         2
# Name: SaleType, dtype: int64

# %%
data["SaleType"].value_counts(normalize = True) #в %соотношении
# Out:
# WD       0.867808
# New      0.083562
# COD      0.029452
# ConLD    0.006164
# ConLI    0.003425
# ConLw    0.003425
# CWD      0.002740
# Oth      0.002055
# Con      0.001370
# Name: SaleType, dtype: float64

# %%
data["CentralAir"].value_counts()
# Out:
# Y    1365
# N      95
# Name: CentralAir, dtype: int64

# %%
pd.get_dummies(data["CentralAir"]).head()
# Out:
#    N  Y
# 0  0  1
# 1  0  1
# 2  0  1
# 3  0  1
# 4  0  1

# %%
def have_CentralAir(row):
    for i in data["CentralAir"]:
        if 'Y' in row['CentralAir']:
            return 1
        else:
            return 0

data['CentralAir'] = data.apply(have_CentralAir, axis=1)

data['CentralAir'].value_counts()
# Out:
# 1    1365
# 0      95
# Name: CentralAir, dtype: int64

# %%
data['CentralAir'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: CentralAir, dtype: int64

# %%
data["SaleType"].value_counts()
# Out:
# WD       1267
# New       122
# COD        43
# ConLD       9
# ConLI       5
# ConLw       5
# CWD         4
# Oth         3
# Con         2
# Name: SaleType, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
data_cat = data["SaleType"]
data_cat_encoded = encoder.fit_transform(data_cat)
data_cat_encoded
# Out:
# array([8, 8, 8, ..., 8, 8, 8])

# %% [markdown]
# 5. Провести углубленный анализ данных (корреляции переменных, визуализация взаимосвязей)

# %%
#выберем наиболее значимые параметры для анализа 
data = data[['Id', 'SaleType', 'SaleCondition', 'MSSubClass', 'LotArea', 'Utilities', 'OverallQual',
              'OverallCond', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'KitchenQual', 'Fireplaces', 'PoolArea']]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 14 columns):
# Id               1460 non-null int64
# SaleType         1460 non-null object
# SaleCondition    1460 non-null object
# MSSubClass       1460 non-null int64
# LotArea          1460 non-null int64
# Utilities        1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# 1stFlrSF         1460 non-null int64
# 2ndFlrSF         1460 non-null int64
# LowQualFinSF     1460 non-null int64
# KitchenQual      1460 non-null object
# Fireplaces       1460 non-null int64
# PoolArea         1460 non-null int64
# dtypes: int64(10), object(4)
# memory usage: 159.8+ KB

# %%
corr_matrix = data.corr()
corr_matrix
# Out:
#                     Id  MSSubClass   LotArea  OverallQual  OverallCond  \
# Id            1.000000    0.011156 -0.033226    -0.028365     0.012609
# MSSubClass    0.011156    1.000000 -0.139781     0.032628    -0.059316
# LotArea      -0.033226   -0.139781  1.000000     0.105806    -0.005636
# OverallQual  -0.028365    0.032628  0.105806     1.000000    -0.091932
# OverallCond   0.012609   -0.059316 -0.005636    -0.091932     1.000000
# 1stFlrSF      0.010496   -0.251758  0.299475     0.476224    -0.144203
# 2ndFlrSF      0.005590    0.307886  0.050986     0.295493     0.028942
# LowQualFinSF -0.044230    0.046474  0.004779    -0.030429     0.025494
# Fireplaces   -0.019772   -0.045569  0.271364     0.396765    -0.023820
# PoolArea      0.057044    0.008283  0.077672     0.065166    -0.001985
#
#               1stFlrSF  2ndFlrSF  LowQualFinSF  Fireplaces  PoolArea
# Id            0.010496  0.005590     -0.044230   -0.019772  0.057044
# ...

# %%
sns.pairplot(data, vars=['SaleCategory', 'OverallQual'],
                 kind='scatter')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SaleCategory'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-2c2536a2a893> in <module>()
# ...

# %%
corr_matrix = data.corr()
corr_matrix["LotArea"].sort_values(ascending=False)
# Out:
# LotArea         1.000000
# 1stFlrSF        0.299475
# Fireplaces      0.271364
# OverallQual     0.105806
# PoolArea        0.077672
# 2ndFlrSF        0.050986
# LowQualFinSF    0.004779
# OverallCond    -0.005636
# Id             -0.033226
# MSSubClass     -0.139781
# Name: LotArea, dtype: float64

# %%
corr_matrix = data.corr()
corr_matrix["SaleType"].sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SaleType'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-7121a80b2719> in <module>()
#       1 corr_matrix = data.corr()
# ...

# %% [markdown]
# 6. Провести сокращение размерности датасета с использованием метода PCA

# %% [markdown]
# 7. Сделать кросс-валидацию данных с использованием подхода K-fold (n_folds=5)

# %% [markdown]
# 8. Решить задачу бинарной классификации и предсказать переменную ‘SalesCategory’ протестировав несколько
# алгоритмов (Logistic Regression, SVM, Random Forest, Gradient Boosting)

# %% [markdown]
# 9. Проверить качество классификации с использованием следующих метрик: Accuracy, F1-Score, Precision, Recall
